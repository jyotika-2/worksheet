# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
df = pd.read_csv("/content/drive/MyDrive/week-2 /Data/Datasets/bank .csv")
df
# Out:
#        age           job   marital  education default  balance housing loan  \
# 0       58    management   married   tertiary      no     2143     yes   no
# 1       44    technician    single  secondary      no       29     yes   no
# 2       33  entrepreneur   married  secondary      no        2     yes  yes
# 3       47   blue-collar   married    unknown      no     1506     yes   no
# 4       33       unknown    single    unknown      no        1      no   no
# ...    ...           ...       ...        ...     ...      ...     ...  ...
# 45206   51    technician   married   tertiary      no      825      no   no
# 45207   71       retired  divorced    primary      no     1729      no   no
# 45208   72       retired   married  secondary      no     5715      no   no
# 45209   57   blue-collar   married  secondary      no      668      no   no
# 45210   37  entrepreneur   married  secondary      no     2971      no   no
#
# ...

# %% [markdown]
# **2.1 Building Blocks of Pandas:**
#
# **1. Data Structure - Series:**

# %%
import pandas as pd
# Creating a simple Series
data = [10, 20, 30, 40]
series = pd.Series(data)
print(series)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# dtype: int64

# %% [markdown]
# **2. Data Structure - Index:**

# %%
# Default Index
import pandas as pd
series = pd.Series([10, 20, 30])
print(series.index)
# Output: RangeIndex(start=0, stop=3, step=1)
# User Defined:
series = pd.Series([10, 20, 30],index=['a','b','c'])
print(series)
# Output:
# a 10
# b 20
# c 30
#datestime index
dates = pd.date_range('2023-01-01', periods=3)
series = pd.Series([10, 20, 30], index=dates)
print(series)
# Output:
# 2023-01-01 10
# 2023-01-02 20
# 2023-01-03 30
#Access
print(series.index)
# Set or Reset Index
series.index = ['x', 'y', 'z'] # Series
# For DataFrame
df = pd.DataFrame({'A': [1, 2]}, index=['row1', 'row2'])
df.reset_index(inplace=True)
# Converts the index into a column
# Out:
# RangeIndex(start=0, stop=3, step=1)
# a    10
# b    20
# c    30
# dtype: int64
# 2023-01-01    10
# 2023-01-02    20
# 2023-01-03    30
# Freq: D, dtype: int64
# DatetimeIndex(['2023-01-01', '2023-01-02', '2023-01-03'], dtype='datetime64[ns]', freq='D')

# %% [markdown]
# **3. Data Structure - DataFrames.**

# %%
#Transforming in-built data structures-DataFrame
#Style-1
import pandas as pd
pd.DataFrame({'Bob': ['I liked it.','It was awful'], 'Sue': ['Pretty good.', 'Bland.']})
#Style-2
pd.DataFrame({'Bob': ['I liked it.', 'It was awful.'], 'Sue': ['Pretty good.', 'Bland.']},

index=['Product A', 'Product B'])
# Out:
#                      Bob           Sue
# Product A    I liked it.  Pretty good.
# Product B  It was awful.        Bland.
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_3.groupby('Bob').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_4.groupby('Sue').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# import pandas as pd
# plt.subplots(figsize=(8, 8))
# ...

# %% [markdown]
# **4. DataFrames - Loading Data to DataFrames.**

# %%
#Importing Data from file
import pandas as pd
# path to your dataset must be given to built in read_csv("Your path") function.
dataset = pd.read_csv("/content/drive/MyDrive/week-2 /Data/Datasets/bank .csv")
dataset.head()
dataset.tail()
dataset.info()
# Run the above code and observe the output.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45211 entries, 0 to 45210
# Data columns (total 17 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        45211 non-null  int64
#  1   job        45211 non-null  object
#  2   marital    45211 non-null  object
#  3   education  45211 non-null  object
#  4   default    45211 non-null  object
#  5   balance    45211 non-null  int64
#  6   housing    45211 non-null  object
#  7   loan       45211 non-null  object
#  8   contact    45211 non-null  object
#  9   day        45211 non-null  int64
#  10  month      45211 non-null  object
#  11  duration   45211 non-null  int64
#  12  campaign   45211 non-null  int64
#  13  pdays      45211 non-null  int64
#  14  previous   45211 non-null  int64
#  15  poutcome   45211 non-null  object
#  16  y          45211 non-null  object
# dtypes: int64(7), object(10)
# memory usage: 5.9+ MB

# %% [markdown]
# **5. DataFrames - Writing DataFrames to CSV.**

# %%
#Importing Data from file
import pandas as pd
data = {'Name': ['Alice', 'Bob', 'Charlie'],'City': ['New York', 'San Francisco', 'Los Angeles']}
df = pd.DataFrame(data) # creating a DataFrame
#Writing DataFrame to csv.
df.to_csv('output.csv', index=False)
# Run the above code and observe the output.

# %% [markdown]
# **2.2 Basic Operation on Data: Data Inspection and Exploration:**

# %% [markdown]
# **1. First Data Inspection and Exploration:**

# %%
import pandas as pd
# Sample DataFrame
data = {
'Name': ['Alice', 'Bob', 'Charlie'],
'Age': [25, 30, 35],
'Salary': [50000, 60000, 70000]
}
df = pd.DataFrame(data)
# View the first two rows
print(df.head(2))
# View the last row
print(df.tail(1))
# DataFrame information
print(df.info())
# Summary statistics
print(df.describe())
# Check dimensions of the DataFrame
print(f"The DataFrame has {df.shape[0]} rows and {df.shape[1]} columns.")
# Access the ’Age’ column
print(df['Age'])
# Select rows by numerical index
print(df.iloc[0]) # First row
# Select rows by condition
print(df.loc[df['Age'] > 30]) # Rows where Age > 30
# Out:
#     Name  Age  Salary
# 0  Alice   25   50000
# 1    Bob   30   60000
#       Name  Age  Salary
# 2  Charlie   35   70000
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    3 non-null      object
#  1   Age     3 non-null      int64
#  2   Salary  3 non-null      int64
# dtypes: int64(2), object(1)
# memory usage: 200.0+ bytes
# None
#         Age   Salary
# count   3.0      3.0
# mean   30.0  60000.0
# std     5.0  10000.0
# min    25.0  50000.0
# 25%    27.5  55000.0
# 50%    30.0  60000.0
# 75%    32.5  65000.0
# max    35.0  70000.0
# The DataFrame has 3 rows and 3 columns.
# 0    25
# 1    30
# 2    35
# Name: Age, dtype: int64
# Name      Alice
# Age          25
# Salary    50000
# Name: 0, dtype: object
#       Name  Age  Salary
# 2  Charlie   35   70000

# %%
import pandas as pd
# Sample DataFrame
data = {
'Name': ['Alice', 'Bob', 'Charlie'],
'Age': [25, 30, None],
'Salary': [50000, 60000, 55000]
}
df = pd.DataFrame(data)
# Check info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    3 non-null      object
#  1   Age     2 non-null      float64
#  2   Salary  3 non-null      int64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 200.0+ bytes

# %%
# Generate descriptive statistics
import pandas as pd
# Sample DataFrame
data = {
'Name': ['Alice', 'Bob', 'Charlie'],
'Age': [25, 30, None],
'Salary': [50000, 60000, 55000]
}
df = pd.DataFrame(data)
# Check summary statistics
df.describe() # Generate descriptive statistics
# Out:
#              Age   Salary
# count   2.000000      3.0
# mean   27.500000  55000.0
# std     3.535534   5000.0
# min    25.000000  50000.0
# 25%    26.250000  52500.0
# 50%    27.500000  55000.0
# 75%    28.750000  57500.0
# max    30.000000  60000.0
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_6['Age'].plot(kind='hist', bins=20, title='Age')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_7['Salary'].plot(kind='hist', bins=20, title='Salary')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_8.plot(kind='scatter', x='Age', y='Salary', s=32, alpha=.8)
# ...

# %% [markdown]
# **2. Filtering and Modifying Data:**

# %%
import pandas as pd
df = pd.DataFrame({
'Name': ['Alice', 'Bob', 'Charlie'],
'Age': [25, 30, 35],
'Salary': [50000, 60000, 70000]
})
# Filter rows where Age > 28
filtered_rows = df[df['Age'] > 28]
print(filtered_rows)
#Select Specific Columns
# Select only ’Name’ and ’Salary’ columns
selected_columns = df[['Name', 'Salary']]
print(selected_columns)
# Drop the ’Salary’ column
df_without_salary = df.drop(columns=['Salary'])
print(df_without_salary)
# Drop the row with index 1 (Bob)
df_without_row = df.drop(index=1)
print(df_without_row)
# Add a new column for Bonus
df['Bonus'] = df['Salary'] * 0.1
print(df)
# Out:
#       Name  Age  Salary
# 1      Bob   30   60000
# 2  Charlie   35   70000
#       Name  Salary
# 0    Alice   50000
# 1      Bob   60000
# 2  Charlie   70000
#       Name  Age
# 0    Alice   25
# 1      Bob   30
# 2  Charlie   35
#       Name  Age  Salary
# 0    Alice   25   50000
# 2  Charlie   35   70000
#       Name  Age  Salary   Bonus
# 0    Alice   25   50000  5000.0
# 1      Bob   30   60000  6000.0
# 2  Charlie   35   70000  7000.0

# %%
import pandas as pd

# Sample DataFrame
df = pd.DataFrame({
    'Name': ['Alice', 'Bob', 'Charlie'],
    'Age': [25, 30, 35],
    'Salary': [50000, 60000, 70000]
})

# Drop the 'Salary' column
df_without_salary = df.drop(columns=['Salary'])
print("DataFrame without Salary column:")
print(df_without_salary)

# Drop the row with index 1 (Bob)
df_without_row = df.drop(index=1)
print("\nDataFrame without row at index 1 (Bob):")
print(df_without_row)

# Add a new column for Bonus
df['Bonus'] = df['Salary'] * 0.1
print("\nDataFrame with Bonus column added:")
print(df)
# Out:
# DataFrame without Salary column:
#       Name  Age
# 0    Alice   25
# 1      Bob   30
# 2  Charlie   35
#
# DataFrame without row at index 1 (Bob):
#       Name  Age  Salary
# 0    Alice   25   50000
# 2  Charlie   35   70000
#
# DataFrame with Bonus column added:
#       Name  Age  Salary   Bonus
# 0    Alice   25   50000  5000.0
# 1      Bob   30   60000  6000.0
# 2  Charlie   35   70000  7000.0

# %% [markdown]
# **2.3 Basic Operation on Data - Data Wrangling - Common Data Cleaning
# operations:**
#
# **1. Handling Missing Values:**

# %%
import pandas as pd
from sklearn.datasets import load_iris
import numpy as np

# Load the Iris dataset
iris = load_iris()
iris_df = pd.DataFrame(
    data=np.c_[iris['data'], iris['target']],
    columns=iris['feature_names'] + ['target']
)

# Introduce missing values randomly
np.random.seed(42)
mask = np.random.rand(*iris_df.shape) < 0.1  # 10% chance for missing values
iris_df[mask] = np.nan

# Display missing values count for each column
print("Missing Values in Iris Dataset:")
print(iris_df.isnull().sum())


# Filling missing values with forward fill (ffill), mean, median, and 0
iris_df_ffill = iris_df.ffill()
iris_df_mean = iris_df.fillna(iris_df.mean())
iris_df_median = iris_df.fillna(iris_df.median())
iris_df_zero = iris_df.fillna(0)
# Expand iris_df with filled columns
iris_df_expanded = pd.concat([iris_df, iris_df_ffill.add_suffix("_ffill"),
iris_df_mean.add_suffix("_mean"),iris_df_median.add_suffix("_median"),iris_df_zero.add_suffix("_zero")], axis=1)
# Display the head of the expanded DataFrame
print("\nDataset after Filling Missing Values:")
print(iris_df_expanded.head())
# Out:
# Missing Values in Iris Dataset:
# sepal length (cm)    15
# sepal width (cm)     15
# petal length (cm)    19
# petal width (cm)     15
# target               19
# dtype: int64
#
# Dataset after Filling Missing Values:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               NaN                1.4               0.2
# 2                NaN               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    target  sepal length (cm)_ffill  sepal width (cm)_ffill  \
# 0     0.0                      5.1                     3.5
# 1     0.0                      4.9                     3.5
# 2     0.0                      4.9                     3.2
# ...

# %% [markdown]
# **2. Some Common Operation performed for cleaning data.**

# %%
#--------------------------------------------------------------------
# -----------Trimming Whitespaces:----------------------------------
#--------------------------------------------------------------------
df = pd.DataFrame({"Name": ["Alice ", "Bob "], "Age": [25, 30]})
df["Name"] = df["Name"].str.strip()
#--------------------------------------------------------------------
#-------------Changing Datatype:-------------------------------------
#--------------------------------------------------------------------
df = pd.DataFrame({"Age": ["25", "30", "35"]})
# Change "Age" column data type to integer
df["Age"] = df["Age"].astype(int)
print(df)
#--------------------------------------------------------------------
#-------------Renaming Columns:-------------------------------------
#--------------------------------------------------------------------
# Rename columns
df = pd.DataFrame({"Name": ["Alice", "Bob"], "Age": [25, 30]})
df = df.rename(columns={"Name": "Full Name", "Age": "Years"})
print(df)
#--------------------------------------------------------------------
#--------------Removing Duplicates:-----------------------------------
#--------------------------------------------------------------------
# Remove duplicate rows
df = pd.DataFrame({"Name": ["Alice", "Bob", "Alice"], "Age": [25, 30, 25]})
df = df.drop_duplicates()
print(df)
# Out:
#    Age
# 0   25
# 1   30
# 2   35
#   Full Name  Years
# 0     Alice     25
# 1       Bob     30
#     Name  Age
# 0  Alice   25
# 1    Bob   30

# %% [markdown]
# **3. Data Transformation - DataFrame Reshaping.**

# %%
#------------------Pivoting----------------------------------------
import pandas as pd
# Sample DataFrame
data = {"Date": ["2024-01-01", "2024-01-01", "2024-01-02", "2024-01-02"],
"City": ["Kathmandu", "Pokhara", "Kathmandu", "Pokhara"],
"Temperature": [15, 18, 16, 19]}
df = pd.DataFrame(data)
# Pivot: Reshape data to show cities as columns
pivoted_df = df.pivot(index="Date", columns="City", values="Temperature")
print(pivoted_df)
#---------------------------------------------------------------------------
#---------------------------Melting-----------------------------------------
#---------------------------------------------------------------------------
# Melt: Convert wide data back to long format
melted_df = pd.melt(pivoted_df.reset_index(), id_vars=["Date"],
var_name="City", value_name="Temperature")

print(melted_df)
# Out:
# City        Kathmandu  Pokhara
# Date
# 2024-01-01         15       18
# 2024-01-02         16       19
#          Date       City  Temperature
# 0  2024-01-01  Kathmandu           15
# 1  2024-01-02  Kathmandu           16
# 2  2024-01-01    Pokhara           18
# 3  2024-01-02    Pokhara           19

# %% [markdown]
# **4. Data Transformation - Data Scaling .**

# %%
import pandas as pd
from sklearn.datasets import load_iris
iris = load_iris() # Load the Iris dataset
iris_df = pd.DataFrame(data=iris["data"], columns=iris["feature_names"])
# Min-Max Scaling using Pandas
iris_minmax_scaled = (iris_df - iris_df.min()) / (iris_df.max() - iris_df.min())
print("Original Iris DataFrame:")
print(iris_df.head())
print("\nMin-Max Scaled Iris DataFrame:")
print(iris_minmax_scaled.head()) # Display scaled data
# Out:
# Original Iris DataFrame:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
# Min-Max Scaled Iris DataFrame:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0           0.222222          0.625000           0.067797          0.041667
# 1           0.166667          0.416667           0.067797          0.041667
# 2           0.111111          0.500000           0.050847          0.041667
# 3           0.083333          0.458333           0.084746          0.041667
# 4           0.194444          0.666667           0.067797          0.041667

# %% [markdown]
# **5. Data Transformation - Handling Categorical Variables:**

# %%
import pandas as pd
# Sample DataFrame with ordinal categories
df = pd.DataFrame({"Category": ["Low", "Medium", "High", "Low", "High"]})
# Ordinal encoding using map
ordinal_mapping = {"Low": 1, "Medium": 2, "High": 3}
df["Category_Ordinal"] = df["Category"].map(ordinal_mapping)
print(df)
# Out:
#   Category  Category_Ordinal
# 0      Low                 1
# 1   Medium                 2
# 2     High                 3
# 3      Low                 1
# 4     High                 3

# %%
import pandas as pd
df_municipalities = pd.DataFrame({"Municipality": ["Kathmandu", "Bhaktapur", "Lalitpur", "Madhyapur", "Thimi", "Kirtipur"]})
one_hot_encoding = pd.get_dummies(df_municipalities["Municipality"], prefix="Municipality")
df_encoded = pd.concat([df_municipalities, one_hot_encoding], axis=1)
print(df_encoded)# Display the result
# Out:
#   Municipality  Municipality_Bhaktapur  Municipality_Kathmandu  \
# 0    Kathmandu                   False                    True
# 1    Bhaktapur                    True                   False
# 2     Lalitpur                   False                   False
# 3    Madhyapur                   False                   False
# 4        Thimi                   False                   False
# 5     Kirtipur                   False                   False
#
#    Municipality_Kirtipur  Municipality_Lalitpur  Municipality_Madhyapur  \
# 0                  False                  False                   False
# 1                  False                  False                   False
# 2                  False                   True                   False
# 3                  False                  False                    True
# 4                  False                  False                   False
# 5                   True                  False                   False
#
# ...

# %% [markdown]
# **6. Merging and joining DataFrames:**

# %%
import pandas as pd
# Sample DataFrames
df1 = pd.DataFrame({"A": [1, 2], "B": [3, 4]})
df2 = pd.DataFrame({"A": [5, 6], "B": [7, 8]})
# Row-wise concatenation
combined_rows = pd.concat([df1, df2], axis=0)
print("Row-wise concatenation:")
print(combined_rows)
# Column-wise concatenation
combined_cols = pd.concat([df1, df2], axis=1)
print("\nColumn-wise concatenation:")
print(combined_cols)
# Sample DataFrames
df1 = pd.DataFrame({"ID": [1, 2, 3], "Name": ["Alice", "Bob", "Charlie"]})
df2 = pd.DataFrame({"ID": [2, 3, 4], "Score": [85, 90, 88]})
# Inner join
inner_merged = pd.merge(df1, df2, on="ID", how="inner")
print("Inner Join:")
print(inner_merged)
# Left join
left_merged = pd.merge(df1, df2, on="ID", how="left")
print("\nLeft Join:")
print(left_merged)
# Outer join
outer_merged = pd.merge(df1, df2, on="ID", how="outer")
print("\nOuter Join:")
print(outer_merged)
# Out:
# Row-wise concatenation:
#    A  B
# 0  1  3
# 1  2  4
# 0  5  7
# 1  6  8
#
# Column-wise concatenation:
#    A  B  A  B
# 0  1  3  5  7
# 1  2  4  6  8
# Inner Join:
#    ID     Name  Score
# 0   2      Bob     85
# 1   3  Charlie     90
#
# Left Join:
#    ID     Name  Score
# 0   1    Alice    NaN
# 1   2      Bob   85.0
# 2   3  Charlie   90.0
#
# Outer Join:
#    ID     Name  Score
# 0   1    Alice    NaN
# 1   2      Bob   85.0
# 2   3  Charlie   90.0
# 3   4      NaN   88.0

# %% [markdown]
# **3. To - Do - Task**

# %% [markdown]
# **3.1 Warming Up Exercises - Basic Inspection and Exploration:**
#
# **Problem 1 - Data Read, Write and Inspect:**
#
# **Complete all following Task:**
#
# **• Dataset for the Task: "bank.csv"**
#
# **1. Load the provided dataset and import in pandas DataFrame.**
# **2. Check info of the DataFrame and identify following:**
#
# **(a) columns with dtypes=object**
#
# **(b) unique values of those columns.**
#
# **(c) check for the total number of null values in each column.**
#
# **3. Drop all the columns with dtypes object and store in new DataFrame, also write the DataFrame in
# ”.csv” with name ”banknumericdata.csv”**
#
# **4. Read ”banknumericdata.csv” and Find the summary statistics.**

# %%
import pandas as pd

# Task 1: Load the dataset into a pandas DataFrame
df = pd.read_csv("/content/drive/MyDrive/week-2 /Data/Datasets/bank .csv")

# Task 2: Inspect the DataFrame
# (a) Identify columns with dtype=object
object_columns = df.select_dtypes(include=['object']).columns
print(f"Columns with dtype=object:\n{list(object_columns)}\n")

# (b) Find unique values of those columns
for col in object_columns:
    print(f"Unique values in column '{col}':")
    print(df[col].unique())
    print("\n")

# (c) Check for the total number of null values in each column
null_values = df.isnull().sum()
print(f"Null values in each column:\n{null_values}\n")

# Task 3: Drop columns with dtype=object and write to a new CSV file
numeric_df = df.drop(columns=object_columns)
numeric_df.to_csv("banknumericdata.csv", index=False)

# Task 4: Read the new file and find summary statistics
numeric_data = pd.read_csv("banknumericdata.csv")
print("Summary statistics of the numeric DataFrame:")
print(numeric_data.describe())
# Out:
# Columns with dtype=object:
# ['job', 'marital', 'education', 'default', 'housing', 'loan', 'contact', 'month', 'poutcome', 'y']
#
# Unique values in column 'job':
# ['management' 'technician' 'entrepreneur' 'blue-collar' 'unknown'
#  'retired' 'admin.' 'services' 'self-employed' 'unemployed' 'housemaid'
#  'student']
#
#
# Unique values in column 'marital':
# ['married' 'single' 'divorced']
#
#
# Unique values in column 'education':
# ['tertiary' 'secondary' 'unknown' 'primary']
#
#
# Unique values in column 'default':
# ['no' 'yes']
#
#
# Unique values in column 'housing':
# ['yes' 'no']
#
#
# Unique values in column 'loan':
# ['no' 'yes']
#
#
# Unique values in column 'contact':
# ['unknown' 'cellular' 'telephone']
#
#
# Unique values in column 'month':
# ['may' 'jun' 'jul' 'aug' 'oct' 'nov' 'dec' 'jan' 'feb' 'mar' 'apr' 'sep']
#
#
# Unique values in column 'poutcome':
# ['unknown' 'failure' 'other' 'success']
#
#
# Unique values in column 'y':
# ['no' 'yes']
#
#
# ...

# %% [markdown]
# **Problem 2 - Data Imputations:**
#
# **Complete all the following Task:**
#
# **• Dataset for the Task: "medical_student.csv"**
#
# **1. Load the provided dataset and import in pandas DataFrame.**
#
# **2. Check info of the DataFrame and identify column with missing (null) values.**
# **3. For the column with missing values fill the values using various techniques we discussed above. Try
# to explain why did you select the particular methods for particular column.**
# **4. Check for any duplicate values present in Dataset and do necessary to manage the duplicate items.**
#
# **{Hint: dataset.duplicated.sum()}**

# %%
import pandas as pd

# Task 1: Load the dataset into a pandas DataFrame
df = pd.read_csv(r"/content/drive/MyDrive/week-2 /Data/Datasets/medical_students_dataset.csv")

# Task 2: Check info and identify columns with missing (null) values
print("DataFrame Info:")
df.info()
print("\nMissing Values in Each Column:")
print(df.isnull().sum())

# Task 3: Handle missing values using various imputation techniques
# Example handling
if 'Age' in df.columns:
    df['Age'] = df['Age'].fillna(df['Age'].mean())
    print("Filled missing values in 'Age' with mean.")

# Fill categorical column (e.g., Gender) with mode
if 'Gender' in df.columns:
    df['Gender'] = df['Gender'].fillna(df['Gender'].mode()[0])
    print("Filled missing values in 'Gender' with mode.")

# Fill other columns as needed
if 'Grade' in df.columns:
    df['Grade'] = df['Grade'].fillna(method='ffill')
    print("Filled missing values in 'Grade' using forward fill.")

# Task 4: Check and manage duplicate values
print("\nNumber of Duplicate Rows:", df.duplicated().sum())

df = df.drop_duplicates()
print("\nDuplicates removed. Updated DataFrame:")
print(df.head())

df.to_csv("medical_student_cleaned.csv", index=False)
# Out:
# DataFrame Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200000 entries, 0 to 199999
# Data columns (total 13 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   Student ID      180000 non-null  float64
#  1   Age             180000 non-null  float64
#  2   Gender          180000 non-null  object
#  3   Height          180000 non-null  float64
#  4   Weight          180000 non-null  float64
#  5   Blood Type      180000 non-null  object
#  6   BMI             180000 non-null  float64
#  7   Temperature     180000 non-null  float64
#  8   Heart Rate      180000 non-null  float64
#  9   Blood Pressure  180000 non-null  float64
#  10  Cholesterol     180000 non-null  float64
#  11  Diabetes        180000 non-null  object
#  12  Smoking         180000 non-null  object
# dtypes: float64(9), object(4)
# memory usage: 19.8+ MB
#
# Missing Values in Each Column:
# Student ID        20000
# Age               20000
# ...

# %% [markdown]
# **3.2 Exercises - Data Cleaning and Transformations with ”Titanic Dataset”:**
#
#
# **Dataset Used: "titanic.csv"**
#
# **Problem - 1:**
#
# **Create a DataFrame that is subsetted for the columns ’Name’, ’Pclass’, ’Sex’, ’Age’, ’Fare’, and ’Survived’.**
# **Retain only those rows where ’Pclass’ is equal to 1, representing first-class passengers. What is the mean,
# median, maximum value, and minimum value of the ’Fare’ column?**

# %%
import pandas as pd

# Load the Titanic dataset
df = pd.read_csv("/content/drive/MyDrive/week-2 /Data/Datasets/Titanic-Dataset.csv")

# Subset the DataFrame for specific columns
columns_to_keep = ['Name', 'Pclass', 'Sex', 'Age', 'Fare', 'Survived']
df_subset = df[columns_to_keep]

# Filter the rows where 'Pclass' is equal to 1 (first-class passengers)
first_class_passengers = df_subset[df_subset['Pclass'] == 1]

# Calculate the required statistics for the 'Fare' column
fare_mean = first_class_passengers['Fare'].mean()
fare_median = first_class_passengers['Fare'].median()
fare_max = first_class_passengers['Fare'].max()
fare_min = first_class_passengers['Fare'].min()

# Display the results
print("Statistics for the 'Fare' column (First-Class Passengers):")
print(f"Mean: {fare_mean}")
print(f"Median: {fare_median}")
print(f"Maximum Value: {fare_max}")
print(f"Minimum Value: {fare_min}")
# Out:
# Statistics for the 'Fare' column (First-Class Passengers):
# Mean: 84.1546875
# Median: 60.287499999999994
# Maximum Value: 512.3292
# Minimum Value: 0.0

# %% [markdown]
# **Problem - 2:**
#
# **How many null values are contained in the ’Age’ column in your subsetted DataFrame? Once you’ve found
# this out, drop them from your DataFrame.**

# %%
import pandas as pd

# Load the Titanic dataset
df = pd.read_csv("/content/drive/MyDrive/week-2 /Data/Datasets/Titanic-Dataset.csv")

# Subset the DataFrame for specific columns
columns_to_keep = ['Name', 'Pclass', 'Sex', 'Age', 'Fare', 'Survived']
df_subset = df[columns_to_keep]

# Count the number of null values in the 'Age' column
null_count = df_subset['Age'].isnull().sum()
print(f"Number of null values in the 'Age' column: {null_count}")

# Drop rows where 'Age' is null
df_subset_cleaned = df_subset.dropna(subset=['Age'])

print("\nDataFrame after dropping rows with null values in the 'Age' column:")
print(df_subset_cleaned.info())
# Out:
# Number of null values in the 'Age' column: 177
#
# DataFrame after dropping rows with null values in the 'Age' column:
# <class 'pandas.core.frame.DataFrame'>
# Index: 714 entries, 0 to 890
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      714 non-null    object
#  1   Pclass    714 non-null    int64
#  2   Sex       714 non-null    object
#  3   Age       714 non-null    float64
#  4   Fare      714 non-null    float64
#  5   Survived  714 non-null    int64
# dtypes: float64(2), int64(2), object(2)
# memory usage: 39.0+ KB
# None

# %% [markdown]
# **Problem - 3:**
#
# **The ’Embarked’ column in the Titanic dataset contains categorical data representing the ports of embarka-
# tion:**
#
# **• ’C’ for Cherbourg**
#
# **• ’Q’ for Queenstown**
#
# **• ’S’ for Southampton**
#
# **Task:**
# **1. Use one-hot encoding to convert the ’Embarked’ column into separate binary columns (’Embarked C’,
# ’Embarked Q’, ’Embarked S’).**
#
# **2. Add these new columns to the original DataFrame.**
#
# **3. Drop the original ’Embarked’ column.**
#
# **4. Print the first few rows of the modified DataFrame to verify the changes.**

# %%
import pandas as pd

# Load the Titanic dataset
df = pd.read_csv("/content/drive/MyDrive/week-2 /Data/Datasets/Titanic-Dataset.csv")

# Perform one-hot encoding on the 'Embarked' column
df_encoded = pd.get_dummies(df['Embarked'], prefix='Embarked')

# Add the new columns to the original DataFrame
df = pd.concat([df, df_encoded], axis=1)

# Drop the original 'Embarked' column
df.drop('Embarked', axis=1, inplace=True)

# Display the first few rows of the modified DataFrame to verify changes
print(df.head())
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin  Embarked_C  Embarked_Q  Embarked_S
# 0      0         A/5 21171   7.2500   NaN       False       False        True
# 1      0          PC 17599  71.2833   C85        True       False       False
# 2      0  STON/O2. 3101282   7.9250   NaN       False       False        True
# ...

# %% [markdown]
# **Problem - 4:**
#
# **Compare the mean survival rates (’Survived’) for the different groups in the ’Sex’ column. Draw a visual-
# ization to show how the survival distributions vary by gender.**

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the Titanic dataset
df = pd.read_csv("/content/drive/MyDrive/week-2 /Data/Datasets/Titanic-Dataset.csv")

# Calculate the mean survival rates for different sexes
mean_survival_by_sex = df.groupby('Sex')['Survived'].mean()
print("Mean survival rates by gender:")
print(mean_survival_by_sex)

# Plotting the survival distributions by gender
plt.figure(figsize=(10,6))

# Using seaborn to create a boxplot to visualize the distribution of 'Survived' for different genders
sns.boxplot(x='Sex', y='Survived', data=df)

# Adding labels and title
plt.title('Survival Distribution by Gender')
plt.xlabel('Gender')
plt.ylabel('Survival (0 = No, 1 = Yes)')
plt.show()
# Out:
# Mean survival rates by gender:
# Sex
# female    0.742038
# male      0.188908
# Name: Survived, dtype: float64

# %% [markdown]
# **Problem - 5:**
#
# **Draw a visualization that breaks your visualization from Exercise 3 down by the port of embarkation (’Em-
# barked’). In this instance, compare the ports ’C’ (Cherbourg), ’Q’ (Queenstown), and ’S’ (Southampton).**

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the Titanic dataset
df = pd.read_csv("/content/drive/MyDrive/week-2 /Data/Datasets/Titanic-Dataset.csv")

# One-hot encode the 'Embarked' column (C, Q, S)
df = pd.get_dummies(df, columns=['Embarked'], prefix='Embarked', drop_first=False)

# Set up the visualization
plt.figure(figsize=(10, 6))

# Plot survival distribution by gender and port of embarkation
sns.countplot(x='Survived', hue='Sex', data=df, hue_order=['male', 'female'],
              order=[0, 1], dodge=True)

# Add labels and title
plt.title('Survival Distribution by Gender and Embarked Port')
plt.xlabel('Survival (0 = No, 1 = Yes)')
plt.ylabel('Count')

# Show the plot
plt.tight_layout()
plt.show()
